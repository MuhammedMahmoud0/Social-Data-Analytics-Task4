# %%
import pandas as pd

# %%
df = pd.read_csv("clean.csv")

# %%
def rating_category(rating):
    if pd.isna(rating):
        return "unknown"
    elif rating >= 7:
        return "positive"
    elif rating <= 4:
        return "negative"
    else:
        return "neutral"

# %%
def get_random_known_samples(df, n=50, class_col="class"):
    filtered = df[df[class_col] != "unknown"]
    return filtered.sample(n=min(n, len(filtered)), random_state=None)

# %%
df["class"] = df["rating"].apply(rating_category)
df.head()
# Out:
#    movie_id  movie_title                           category  \
# 0   1265609  War Machine  Action, Science Fiction, Thriller
# 1   1265609  War Machine  Action, Science Fiction, Thriller
# 2   1290821      Shelter            Action, Crime, Thriller
# 3   1290821      Shelter            Action, Crime, Thriller
# 4    799882    The Bluff                   Action, Thriller
#
#                   review_id      author  \
# 0  69ab708d81c7289c60e336d0      Sejian
# 1  69ac9eb2a3bb86eb7679fa5a   MovieGuys
# 2  69845a561eb4bd05d874ad1b  CinemaSerf
# 3  6991409c02122c8a202871e8   MovieGuys
# 4  69a09e10db0e43afc3e8699d   Kashifzia
#
#                                               review  rating  \
# 0  March 9, 2011 (Holy !@#$ I feel old.)\r\n\r\n>...     6.0
# 1  Just in time for the US's war of aggression in...     6.0
# 2  I’ve always loved the idea of living in a remo...     6.0
# 3  "Shelter" is, with one notable exception, a ra...     6.0
# 4  I recently watched **The Bluff (2026)** on Pri...     6.0
#
#                  created_at  \
# 0  2026-03-07T00:25:49.652Z
# 1  2026-03-07T21:54:58.268Z
# 2  2026-02-05T08:52:38.056Z
# 3  2026-02-15T03:42:20.818Z
# 4  2026-02-26T19:25:04.400Z
#
#                                       cleaned_review    class
# 0  march holy feel old distant ufo become terrify...  neutral
# 1  time us war aggression iran come war machine b...  neutral
# 2  eve always loved idea living remote scottish l...  neutral
# 3  shelter one notable exception rather uninspiri...  neutral
# 4  recently watched bluff prime video honest take...  neutral

# %%
sample = get_random_known_samples(df, n=50)
print(len(sample))
sample.head()
# Out:
# 50
#      movie_id               movie_title                            category  \
# 755   1010755  The Strangers: Chapter 3                    Horror, Thriller
# 347   1062722              Frankenstein              Drama, Fantasy, Horror
# 270   1198994                 Send Help            Horror, Thriller, Comedy
# 566    533533                TRON: Ares  Science Fiction, Adventure, Action
# 44    1168190         The Wrecking Crew      Action, Comedy, Crime, Mystery
#
#                     review_id            author  \
# 755  69874b4433f8fea1a85ca315            ROBLOX
# 347  694e8a70219c77e555fb0be6            badelf
# 270  6975ac2f6d953ac475a37f7b            JPV852
# 566  68eb10dbbd6799fdc4786db8             Johan
# 44   6977c2e0ab51e4d706695032  Manuel São Bento
#
#                                                 review  rating  \
# 755  🎬 The Strangers: Chapter 3 – Review\r\n\r\nHon...    10.0
# 347  Guillermo del Toro's "Frankenstein" is visuall...     7.0
# 270  Pretty fun dark comedy-horror that features tw...     7.0
# 566  **SLOP**\r\n\r\nI can't believe people are act...     1.0
# 44   Full review: https://fandomwire.com/the-wrecki...     6.0
#
#                    created_at  \
# 755  2026-02-07T14:25:08.906Z
# 347  2025-12-26T13:15:28.632Z
# 270  2026-01-25T05:37:51.965Z
# 566  2025-10-12T02:22:19.434Z
# 44   2026-01-26T19:39:12.264Z
#
#                                         cleaned_review     class
# 755  a stranger chapter a review honestly stranger ...  positive
# 347  guillermo del torso frankenstein visually sump...  positive
# 270  pretty fun dark comedyhorror feature two solid...  positive
# 566  slop cant believe people actually saying good ...  negative
# 44   full review rating wrecking crew competent act...   neutral

# %%
len(sample[sample["class"] == "unknown"]["review"])
# Out:
# 0

# %%
sample = pd.read_csv("sample_2.csv")

# %%
from sklearn.metrics import cohen_kappa_score

# def compute_kappa(df, col1="class_1", col2="class_2", ignore_unknown=True):
def compute_kappa(df, col1="class_1", col2="class_2"):
    data = df[[col1, col2]].copy()

    # if ignore_unknown:
    #     data = data[(data[col1] != "unknown") & (data[col2] != "unknown")]

    return cohen_kappa_score(data[col1], data[col2])

# %%
kappa = compute_kappa(sample)
print("Cohen's Kappa:", kappa)
# Out:
# Cohen's Kappa: 0.7706422018348624
